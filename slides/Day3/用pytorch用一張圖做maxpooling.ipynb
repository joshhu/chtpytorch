# %%
import numpy as np
import cv2
import skimage.measure
from matplotlib import pyplot as plt
import torch

img = cv2.imread('messi.jpg')[:,:,::-1] /255


aa = skimage.measure.block_reduce(img, (12,12,1), np.mean)

plt.imshow(img)
plt.show()
print(aa.shape)
# Out:
# (54, 54, 3)

# %%
t = torch.from_numpy(img).view(1,*img.shape)
b = torch.nn.functional.max_pool3d(t,(5, 5, 1))
c = b.numpy()

plt.imshow(c[0])
plt.show()
print(c[0].shape)
# Out:
# (128, 128, 3)

# %%
weight = torch.
torch.nn.functional.conv3d(t, weight, bias=None, stride=1, padding=0, dilation=1, groups=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-7a96e55ceab1> in <module>()
# ----> 1 conv = torch.nn.functional.conv3d(t,2,2,1)
#
# TypeError: conv3d(): argument 'weight' (position 2) must be Tensor, not int
